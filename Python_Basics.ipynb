# %%
age = 25
salary = 65000.50
name = "Ved"
is_student = True
print(age,salary)
# Out:
# 25 65000.5

# %%
scores = [78, 85, 90, 66]
student = {
    "name": "Alex",
    "age": 24,
    "major": "CS"
}
print(f"{student}\n{scores}")
# Out:
# {'name': 'Alex', 'age': 24, 'major': 'CS'}
# [78, 85, 90, 66]

# %%
for score in scores:
    print(score)

# DS-style
squared_scores = [s**2 for s in scores]
# Out:
# 78
# 85
# 90
# 66
